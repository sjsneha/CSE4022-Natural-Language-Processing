# %% [markdown]
# # NLTK Hands On Day 2
#
# # Details:03-02-2023
#
# # Topic: Web Scrapping and Stemmers

# %%
from urllib import request

# %%
# Task: Scrape Data from Web
url="https://www.gutenberg.org/files/98/98-0.txt"

# %%
response=request.urlopen(url)

# %%
raw=response.read().decode('utf8')  //reading after decoding

# %%
import nltk
from nltk.tokenize import word_tokenize
tokens=word_tokenize(raw)

# %%
print(tokens[:200])
# Out:
# ['\ufeffThe', 'Project', 'Gutenberg', 'eBook', 'of', 'A', 'Tale', 'of', 'Two', 'Cities', ',', 'by', 'Charles', 'Dickens', 'This', 'eBook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'in', 'the', 'United', 'States', 'and', 'most', 'other', 'parts', 'of', 'the', 'world', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions', 'whatsoever', '.', 'You', 'may', 'copy', 'it', ',', 'give', 'it', 'away', 'or', 're-use', 'it', 'under', 'the', 'terms', 'of', 'the', 'Project', 'Gutenberg', 'License', 'included', 'with', 'this', 'eBook', 'or', 'online', 'at', 'www.gutenberg.org', '.', 'If', 'you', 'are', 'not', 'located', 'in', 'the', 'United', 'States', ',', 'you', 'will', 'have', 'to', 'check', 'the', 'laws', 'of', 'the', 'country', 'where', 'you', 'are', 'located', 'before', 'using', 'this', 'eBook', '.', 'Title', ':', 'A', 'Tale', 'of', 'Two', 'Cities', 'A', 'Story', 'of', 'the', 'French', 'Revolution', 'Author', ':', 'Charles', 'Dickens', 'Release', 'Date', ':', 'Janu
# ...

# %%
#Read about BeautifulSoup
#Preprocessing- RE to clean any html tags
#PoS Tagging
#!!

# %%
#PorterStemmer
import nltk
from nltk.stem import PorterStemmer
porter=PorterStemmer()
porter.stem('happiness')
# Out:
# 'happi'

# %%
porter.stem('cacti')
# Out:
# 'cacti'

# %%
porter.stem('joyous')
# Out:
# 'joyou'

# %%
#LancasterStemmer
import nltk
from nltk.stem import LancasterStemmer
porter=LancasterStemmer()
porter.stem('happiness')
# Out:
# 'happy'

# %%
porter.stem('joyous')
# Out:
# 'joy'

# %%
porter.stem('cacti')
# Out:
# 'cact'

# %%
#RegexpStemmer
#RE or Lemmatizers might work with words like 'cacti'
import nltk
from nltk.stem import RegexpStemmer
regex=RegexpStemmer('ing')
regex.stem('walking'))
# Out:
# 'walk'

# %%
porter.stem('cacti')
# Out:
# 'cacti'

# %%
#SnowballStemmer
import nltk
from nltk.stem import SnowballStemmer
snow=SnowballStemmer('french')
snow.stem('manges') #Wrong (Should be mange)
# Out:
# 'mang'

# %%
snow.stem('neuf') #Correct
# Out:
# 'neuf'

# %%
snow.stem('robuste') #Correct
# Out:
# 'robust'

# %%
#Stemming an entire passage.
for i in tokens:
    print(porter.stem(i))
# Out:
# ﻿The
# Project
# Gutenberg
# eBook
# of
# A
# Tale
# of
# Two
# Cities
# ,
# by
# Charles
# Dickens
# This
# eBook
# is
# for
# the
# use
# of
# anyone
# anywhere
# in
# the
# United
# States
# and
# most
# other
# parts
# of
# the
# world
# at
# no
# cost
# and
# with
# almost
# no
# restrictions
# whatsoever
# .
# You
# may
# copy
# it
# ,
# give
# it
# away
# or
# re-use
# it
# under
# the
# terms
# of
# the
# Project
# Gutenberg
# License
# included
# with
# this
# eBook
# or
# online
# at
# www.gutenberg.org
# .
# If
# you
# are
# not
# located
# in
# the
# United
# States
# ,
# you
# will
# have
# to
# check
# the
# laws
# of
# the
# country
# where
# you
# are
# located
# before
# us
# this
# eBook
# .
# Title
# :
# A
# Tale
# of
# Two
# Cities
# A
# Story
# of
# the
# French
# Revolution
# Author
# :
# Charles
# Dickens
# Release
# Date
# :
# January
# ,
# 1994
# [
# eBook
# #
# 98
# ]
# [
# Most
# recently
# updated
# :
# December
# 20
# ,
# 2020
# ]
# Language
# :
# ...

# %%
#from nltk import PorterStemmer
#porter=PorterStemmer()
#text='A paragraph is a self-contained unit of discourse in writing dealing with a particular point or idea. Though not required by the orthographic conventions of any language with a writing system, paragraphs are a conventional means of organizing extended segments of prose.'
#stemmed=[porter.stem(token) for token in text,split("")]

# %%
stemmed=[porter.stem(i) for i in tokens]
print(stemmed[:200])
# Out:
# ['\ufeffThe', 'Project', 'Gutenberg', 'eBook', 'of', 'A', 'Tale', 'of', 'Two', 'Cities', ',', 'by', 'Charles', 'Dickens', 'This', 'eBook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'in', 'the', 'United', 'States', 'and', 'most', 'other', 'parts', 'of', 'the', 'world', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions', 'whatsoever', '.', 'You', 'may', 'copy', 'it', ',', 'give', 'it', 'away', 'or', 're-use', 'it', 'under', 'the', 'terms', 'of', 'the', 'Project', 'Gutenberg', 'License', 'included', 'with', 'this', 'eBook', 'or', 'online', 'at', 'www.gutenberg.org', '.', 'If', 'you', 'are', 'not', 'located', 'in', 'the', 'United', 'States', ',', 'you', 'will', 'have', 'to', 'check', 'the', 'laws', 'of', 'the', 'country', 'where', 'you', 'are', 'located', 'before', 'us', 'this', 'eBook', '.', 'Title', ':', 'A', 'Tale', 'of', 'Two', 'Cities', 'A', 'Story', 'of', 'the', 'French', 'Revolution', 'Author', ':', 'Charles', 'Dickens', 'Release', 'Date', ':', 'January
# ...

# %%
para="There were a king with a large jaw and a queen with a plain face, on the throne of England there were a king with a large jaw and a queen with a fair face, on the throne of France. In both countries it was clearerthan crystal to the lords of the State preserves of loaves and fishes,that things in general were settled for ever."
stemmer2=[porter.stem(i) for i in para.split(" ")]

# %%
print(stemmer2)
# Out:
# ['There', 'were', 'a', 'k', 'with', 'a', 'large', 'jaw', 'and', 'a', 'queen', 'with', 'a', 'plain', 'face,', 'on', 'the', 'throne', 'of', 'England', 'there', 'were', 'a', 'k', 'with', 'a', 'large', 'jaw', 'and', 'a', 'queen', 'with', 'a', 'fair', 'face,', 'on', 'the', 'throne', 'of', 'France.', 'In', 'both', 'countries', 'it', 'was', 'clearerthan', 'crystal', 'to', 'the', 'lords', 'of', 'the', 'State', 'preserves', 'of', 'loaves', 'and', 'fishes,that', 'ths', 'in', 'general', 'were', 'settled', 'for', 'ever.']

# %%
from nltk.stem import WordNetLemmatizer
lemma=WordNetLemmatizer()
print(lemma.lemmatize("cacti"))
# Out:
# cactus

# %%
print(lemma.lemmatize("mice"))
# Out:
# mouse

# %%
print(lemma.lemmatize("am", pos='v'))
# Out:
# be

# %%
print(lemma.lemmatize("better", pos='a')) #Adjective
# Out:
# good
